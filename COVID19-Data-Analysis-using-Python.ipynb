# %% [markdown]
# # COVID19 Data Analysis using Python.

# %% [markdown]
# The material and all the rights belong to Coursera.

# %% [markdown]
# #### Step 1: Import all the required modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print('Modules imported successfully!')
# Out:
# Modules imported successfully!

# %% [markdown]
# #### Step 2: Download dataset and save in csv format.

# %%
corona_dataset = pd.read_csv(r'C:\Users\RK7614\Downloads\covid19_Confirmed_dataset.txt')
corona_dataset.to_csv(r'C:\Users\RK7614\Desktop\Research\covid19_Confirmed_dataset.csv', index=None)
print('Dataset converted from txt to csv and saved successfully!')
# Out:
# Dataset converted from txt to csv and saved successfully!

# %% [markdown]
# #### Step 3: View and modify dataset.

# %%
corona_dataset.head(7)
# Out:
#   Province/State       Country/Region      Lat     Long  1/22/20  1/23/20  \
# 0            NaN          Afghanistan  33.0000  65.0000        0        0
# 1            NaN              Albania  41.1533  20.1683        0        0
# 2            NaN              Algeria  28.0339   1.6596        0        0
# 3            NaN              Andorra  42.5063   1.5218        0        0
# 4            NaN               Angola -11.2027  17.8739        0        0
# 5            NaN  Antigua and Barbuda  17.0608 -61.7964        0        0
# 6            NaN            Argentina -38.4161 -63.6167        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  \
# 0        0        0        0        0  ...     1092     1176     1279
# 1        0        0        0        0  ...      609      634      663
# 2        0        0        0        0  ...     2811     2910     3007
# 3        0        0        0        0  ...      717      723      723
# ...

# %%
corona_dataset.shape
# Out:
# (266, 104)

# %%
corona_dataset.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20',
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20'],
#       dtype='object', length=104)

# %%
corona_dataset.drop(['Lat',
                   'Long'],
                   axis=1,
                   inplace=True)

# %%
corona_dataset.head(7)
# Out:
#   Province/State       Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0            NaN          Afghanistan        0        0        0        0
# 1            NaN              Albania        0        0        0        0
# 2            NaN              Algeria        0        0        0        0
# 3            NaN              Andorra        0        0        0        0
# 4            NaN               Angola        0        0        0        0
# 5            NaN  Antigua and Barbuda        0        0        0        0
# 6            NaN            Argentina        0        0        0        0
#
#    1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  \
# 0        0        0        0        0  ...     1092     1176     1279
# 1        0        0        0        0  ...      609      634      663
# 2        0        0        0        0  ...     2811     2910     3007
# 3        0        0        0        0  ...      717      723      723
# ...

# %% [markdown]
# #### Step 4: Aggregating the rows by country

# %%
corona_aggregated=corona_dataset.groupby('Country/Region').sum()
corona_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
corona_aggregated.shape
# 187 countries , 100 dates
# Out:
# (187, 100)

# %% [markdown]
# #### Step 5: Visualizing data for a country viz. China

# %%
corona_aggregated.loc["China"]
# Out:
# 1/22/20      548
# 1/23/20      643
# 1/24/20      920
# 1/25/20     1406
# 1/26/20     2075
#            ...
# 4/26/20    83912
# 4/27/20    83918
# 4/28/20    83940
# 4/29/20    83944
# 4/30/20    83956
# Name: China, Length: 100, dtype: int64

# %% [markdown]
# #### Find a good measure, describing the spread of virus countrywide.

# %%
corona_aggregated.loc['China'].plot()
plt.legend()
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
pd.set_option('max_rows', None)
corona_aggregated
# Out:
#                                   1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                             0        0        0        0        0
# Albania                                 0        0        0        0        0
# Algeria                                 0        0        0        0        0
# Andorra                                 0        0        0        0        0
# Angola                                  0        0        0        0        0
# Antigua and Barbuda                     0        0        0        0        0
# Argentina                               0        0        0        0        0
# Armenia                                 0        0        0        0        0
# Australia                               0        0        0        0        4
# Austria                                 0        0        0        0        0
# Azerbaijan                              0        0        0        0        0
# ...

# %%
corona_aggregated.loc['India'].plot()
corona_aggregated.loc['US'].plot()
corona_aggregated.loc['Germany'].plot()
plt.legend()
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
corona_aggregated.loc['China'][:3].plot()
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %% [markdown]
# 1st 24hrs : an increase in case(550-650) by 100.
# 2nd 24hrs : an increase in case(650-900) by 250.
# Need to find a measure, say average or maximum number of new cases.
#
# NOTE: To enter a line break add 2 trailing whitespaces after the sentence. 2 consecutive line breaks for paragraph break.

# %% [markdown]
# #### Step 6: Find the first derivative of the curve.
# First derivative (instantaneous rate of change) of a function tells the slope of the tangent of the curve.
# Tangent +ve : increase in curve
# Tangent -ve : decrease in curve

# %%
corona_aggregated.loc['China'].diff().plot()
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %% [markdown]
# The graph shows us the infection rate day by day and we want the maximum number.

# %%
corona_aggregated.loc['China'].diff().max()
#in only 24hrs, difference was 15136.
# Out:
# 15136.0

# %%
corona_aggregated.loc['India'].diff().max()
#in only 24hrs, difference was 1893.
# Out:
# 1893.0

# %%
corona_aggregated.loc['Italy'].diff().max()
#in only 24hrs, difference was 6557.
# Out:
# 6557.0

# %% [markdown]
# #### Step 7: Find the maximum infection rate for all the countries.

# %%
countries = list(corona_aggregated.index)
max_infections = []
for c in countries:
    max_infections.append(corona_aggregated.loc[c].diff().max())
max_infections
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
corona_aggregated['max_infections'] = max_infections
corona_aggregated.head(5)
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# #### Step 8: Prepare dataframe with countries and infections

# %%
corona_data=pd.DataFrame(corona_aggregated['max_infections'])
corona_data
# Out:
#                                   max_infections
# Country/Region
# Afghanistan                                232.0
# Albania                                     34.0
# Algeria                                    199.0
# Andorra                                     43.0
# Angola                                       5.0
# Antigua and Barbuda                          6.0
# Argentina                                  291.0
# Armenia                                    134.0
# Australia                                  497.0
# Austria                                   1321.0
# Azerbaijan                                 105.0
# Bahamas                                      7.0
# Bahrain                                    301.0
# Bangladesh                                 641.0
# Barbados                                    12.0
# Belarus                                   1485.0
# Belgium                                   2454.0
# Belize                                       4.0
# ...

# %% [markdown]
# #### Step 9:
# - Import WorldHappinessReport.txt report and convert to csv.
# - Select needed coulmns.
# - Join the datasets.
# - Calculate the correlations as the result of our analysis.

# %% [markdown]
# #### Import txt and save as csv file.

# %%
happiness_report=pd.read_csv(r'C:\Users\RK7614\Downloads\worldwide_happiness_report.txt')
happiness_report.to_csv(r'C:\Users\RK7614\Desktop\Research\worldwide_happiness_report.csv', index=None)
print('Document saved successfully!')
# Out:
# Document saved successfully!

# %%
happiness_report.head(6)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# ...

# %% [markdown]
# #### Drop the non-required columns

# %%
useless_columns = ['Overall rank', 'Score', 'Generosity', 'Perceptions of corruption']
happiness_report.drop(useless_columns, axis=1, inplace=True)
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index('Country or region', inplace=True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# #### Join the two datasets prepared

# %%
corona_data.head()
# Out:
#                 max_infections
# Country/Region
# Afghanistan              232.0
# Albania                   34.0
# Algeria                  199.0
# Andorra                   43.0
# Angola                     5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
#Inner join
data = corona_data.join(happiness_report,
                       how='inner')
data.head()
# Out:
#              max_infections  GDP per capita  Social support  \
# Afghanistan           232.0           0.350           0.517
# Albania                34.0           0.947           0.848
# Algeria               199.0           1.002           1.160
# Argentina             291.0           1.092           1.432
# Armenia               134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# #### Calculate correlation matrix

# %%
data.corr()
# Out:
#                               max_infections  GDP per capita  Social support  \
# max_infections                      1.000000        0.250118        0.191958
# GDP per capita                      0.250118        1.000000        0.759468
# Social support                      0.191958        0.759468        1.000000
# Healthy life expectancy             0.289263        0.863062        0.765286
# Freedom to make life choices        0.078196        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_infections                               0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_infections                                    0.078196
# ...

# %% [markdown]
# #### Let's visualize the results we got such that everybody can understand it.

# %%
data.head()
# Out:
#              max_infections  GDP per capita  Social support  \
# Afghanistan           232.0           0.350           0.517
# Albania                34.0           0.947           0.848
# Algeria               199.0           1.002           1.160
# Argentina             291.0           1.092           1.432
# Armenia               134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Let's compare GDP and maxi_infections

# %%
x=data['GDP per capita']
y=data['max_infections']
sns.scatterplot(x,y)

#we can see values need different scaling
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infections'>

# %%
# We'll apply log scaling to y
x=data['GDP per capita']
y=data['max_infections']
sns.scatterplot(x,np.log(y))

#we can see +ve correlation
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infections'>

# %%
#RegPlot
x=data['GDP per capita']
y=data['max_infections']
sns.regplot(x,np.log(y))

#line fitter, +ve slope seen
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infections'>

# %% [markdown]
# ### Social support vs max infections

# %%
x=data['Social support']
y=data['max_infections']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='max_infections'>

# %%
x=data['Social support']
y=data['max_infections']
sns.regplot(x,np.log(y))
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# <AxesSubplot:xlabel='Social support', ylabel='max_infections'>

# %% [markdown]
# ### Healthy life expectancy vs max infections

# %%
x=data['Healthy life expectancy']
y=data['max_infections']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infections'>

# %%
x=data['Healthy life expectancy']
y=data['max_infections']
sns.regplot(x,np.log(y))
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infections'>

# %% [markdown]
# ### Freedom to make life choices vs max infections

# %%
x=data['Freedom to make life choices']
y=data['max_infections']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infections'>

# %%
x=data['Freedom to make life choices']
y=data['max_infections']
sns.regplot(x,np.log(y))
# Out:
# C:\Users\RK7614\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infections'>
